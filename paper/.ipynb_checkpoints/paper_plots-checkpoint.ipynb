# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
import os
cwd = os.getcwd()
os.chdir(cwd + '/..')
from gcex.utils.io import cosmic_read_helper
from gcex.utils.getlcs import get_lcs
os.chdir(cwd)

# %% [markdown]
# # Timing

# %%
fig, ax1 = plt.subplots(1, 1, sharex=True)
fig.set_size_inches(12, 8)
plt.subplots_adjust(hspace=0.0)
num_pdots = 256

tick_fontsize = 18
label_fontsize = 20

# get data
phase_bin_list = [15, 50]
num_points = [100, 1000]
colors = ['blue', 'red']
lss = ['solid', 'dashed']

for nps, ls in zip(num_points, lss):
    for pb, color in zip(phase_bin_list, colors): 
        num_freqs, total, per = np.load('data/timing_results_{}_{}.npy'.format(pb, nps))
        #ax1.plot(np.log2(num_freqs*num_pdots), np.log10(total))
        label = '{} Phase Bins, {} Light Curve Points'.format(pb, nps)
        ax1.plot(np.log2(num_freqs*num_pdots), np.log10(per), label=label, color=color, ls=ls)
        
        #if nps == 100 and pb == 50:
        #    num_freqs, total, per = np.load('data/pdot_check_timing_results_{}_{}.npy'.format(pb, nps))
        #    #ax1.plot(np.log2(num_freqs*num_pdots), np.log10(total))
        #    label = '{} Phase Bins, {} Light Curve Points'.format(pb, nps)
        #    ax1.plot(np.log2(num_freqs*num_pdots), np.log10(per), label=label, color='k', ls=ls)
    
for tick in ax1.xaxis.get_major_ticks():
    tick.label.set_fontsize(tick_fontsize) 
    
time_ticks = [-8, -7, -6, -5]
time_tick_labels = [r'$10^{1}$', r'$10^{2}$', r'$10^{3}$', r'$10^{4}$']
ax1.set_yticks(time_ticks)
ax1.set_yticklabels(time_tick_labels, fontsize=tick_fontsize)
ax1.set_ylabel('Time per light curve per search point (ns)', fontsize=label_fontsize)
ax1.set_xlabel(r"log$_2$(Number of Search Points)", fontsize=label_fontsize)
ax1.legend(loc='upper right', prop={'size':16})
fig.savefig("figures/timing_example.pdf", dpi=200)

# %% [markdown]
# # Light Curve Example

# %%
input_dict = {
                 'f_gw[Hz]': array([0.00357429]),
                 'f_dot_total [yr^(-2)]': array([-0.03077094]),
                 'm1 [msun]': array([0.07231938]),
                 'm2[msun]': array([0.7526806]),
                 'xGx[kpc]': array([-1075.95056152]),
                 'yGx[kpc]': array([-214.06079102]),
                 'zGx[kpc]': array([91.58611298]),
                 'm1': array([0.07231938]),
                 'm2': array([0.7526806]),
                 'q': array([10.40773013]),
                 'm_tot': array([0.82499998]),
                 'd': array([110.08540544]),
                 'period': array([0.0064763]),
                 'Pdot': array([-4.837086e-12]),
                 'incl': array([100.]),
                 'sbratio': array([0.5])
             }
lcs = get_lcs(input_dict, min_pts=95, max_pts=105, verbose=25, mean_dt=3, sig_t=2)
# Out:
# 0

# %%
input_dict
# Out:
# {'f_gw[Hz]': array([0.00357429]),
#  'f_dot_total [yr^(-2)]': array([-0.03077094]),
#  'm1 [msun]': array([0.07231938]),
#  'm2[msun]': array([0.7526806]),
#  'xGx[kpc]': array([-1075.95056152]),
#  'yGx[kpc]': array([-214.06079102]),
#  'zGx[kpc]': array([91.58611298]),
#  'm1': array([0.07231938]),
#  'm2': array([0.7526806]),
#  'q': array([10.40773013]),
#  'm_tot': array([0.82499998]),
#  'd': array([110.08540544]),
#  'period': array([0.0064763]),
#         [188.17749961,   1.        ,   0.        ],
#         [190.61623005,   1.        ,   0.        ],
#         [191.55286671,   0.99699833,   0.        ],
#         [197.20893768,   1.        ,   0.        ],
#         [197.56060169,   1.        ,   0.        ],
#         [200.75672336,   1.        ,   0.        ],
#         [204.16694767,   1.        ,   0.        ],
#         [209.84119821,   1.        ,   0.        ],
#         [213.99324025,   0.99902365,   0.        ],
#         [220.9489666 ,   1.        ,   0.        ],
#         [221.91423602,   1.        ,   0.        ],
#         [222.37736573,   1.        ,   0.        ],
#         [223.81332013,   1.        ,   0.        ],
#         [226.69231359,   1.        ,   0.        ],
#         [229.98422062,   1.        ,   0.        ],
#         [233.31900224,   1.        ,   0.        ],
#         [236.25248488,   1.        ,   0.        ],
#         [239.68202787,   1.        ,   0.        ],
#         [241.63097885,   1.        ,   0.        ],
#         [243.77052138,   1.        ,   0.        ],
#         [251.4272116 ,   1.        ,   0.        ],
#         [254.9598992 ,   1.        ,   0.        ],
#         [258.70045798,   1.        ,   0.        ],
#         [261.70112742,   1.        ,   0.        ],
#         [265.81833323,   1.        ,   0.        ],
#         [270.29938712,   1.        ,   0.        ],
#         [272.15975378,   0.92147446,   0.        ],
#         [274.98900369,   1.        ,   0.        ],
#         [278.34250951,   1.        ,   0.        ],
#         [283.32868902,   1.        ,   0.        ],
#         [284.09796891,   1.        ,   0.        ],
#         [285.97026537,   1.        ,   0.        ],
#         [289.14848402,   1.        ,   0.        ],
#         [290.80652   ,   1.        ,   0.        ],
#         [292.64212745,   1.        ,   0.        ],
#         [297.07672494,   1.        ,   0.        ]])]

# %%
titles = ['Lightcurve', 'Correct Period', 'Wrong Period']

fig, ax = plt.subplots(1, 3, sharey=True)
plt.subplots_adjust(wspace=0.1)
fig.set_size_inches(15.0, 5.0)
ax = ax.ravel()

for f in lc:
    if f == 'u_':
        continue
    t = lc[f]['OpSimDates']
    mags = lc[f]['magObs']
    mags = (mags - np.median(mags))/np.std(mags)
    print(f)
    ax[0].plot(lc[f]['OpSimDates'] - min(lc[f]['OpSimDates']), mags, '.')
    ax[1].plot((lc[f]['OpSimDates'] % period_check)/period_check, mags, '.')
    ax[2].plot((lc[f]['OpSimDates'] % 7.8923)/ 7.8923, mags, '.')

ax[0].set_ylim(5, -1)

for (ax_i, title) in zip(ax, titles):
    ax_i.set_title(title, fontsize=20)
    ax_i.tick_params('both', labelsize=14)
    
#ax[1].set_xticks([0.0, 0.2, 0.4, 0.6, 0.8])
for ax_i in ax[1:]:
    ax_i.set_xlim(0.0, 1.0)
    ax_i.xaxis.set_minor_locator(AutoMinorLocator(2))
    ax_i.yaxis.set_minor_locator(AutoMinorLocator(2))
    ax_i.grid(True, which='both')
    ax_i.set_xlabel('Normalized Folded Phase', fontsize=16)
    
ax[0].set_xlabel('Time (days)', fontsize=16)
ax[0].set_ylabel('Normalized Magnitude', fontsize=16)
fig.savefig('ce_example.pdf', dpi=200)
# Out:
# array([ 0.43338199,  0.66229108,  0.6808915 ,  0.71731486,  0.76057347,
#         0.7789173 ,  0.77018705,  0.821808  ,  1.0955825 ,  1.89102545,
#         3.4791568 ,  6.66149897, 12.97477444, 25.50057105, 50.39638989,
#        99.70463566])
